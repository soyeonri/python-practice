# %% [markdown]
# # **그리디 알고리즘**

# %% [markdown]
# *   현재 상황에서 지금 당장 좋은 것만 고르는 방법
# *   정당성 분석이 중요
# *   최적의 해
# *   코딩테스트에서는 탐욕법으로 얻은 해가  최적의 해가 되는 상황에서 이를 추론할 수 있어야 풀리도록 출제

# %% [markdown]
# **거스름 돈 문제**
#
# ![거스름돈 문제.PNG](data:image/png;base64,...)

# %% [markdown]
# *   가장 큰 화폐 단위부터
# *   화폐의 종류가 k라고 할 때, 소스코드의 시간 복잡도는 O(k)

# %%
change = 1250
count = 0

array = [500, 100, 50, 10]

for coin in array:
  count += change // coin
  change %= coin 

print(count)
# Out:
# 5

# %% [markdown]
# # **1이 될 때 까지**
#
# *  최대한 많이 나누기

# %% [markdown]
# ![1이 될때 까지.PNG](data:image/png;base64,...)

# %% [markdown]
# ![1이 될 때 까지 예시.PNG](data:image/png;base64,...)

# %%
n, k = map(int, input().split())

result = 0

while True:
    target = (n // k) * k #가장 가까운 k로 나누어지는 수 찾기
    result += (n - target) #1을 빼는 연산횟수
    n = target

    if n < k:
      break #n이 k보다 적어 더 이상 나눌 수 없을 때 반복문 탈출

    result += 1 #k로 나누어 지는 연산은 1번 수행
    n //= k

result += (n - 1)
print(result)
# Out:
# 25 5
# 2

# %% [markdown]
# # **곱하기 혹은 더하기**
#
#
# *   연산자를 넣어 만들어질 수 있는 가장 큰 수
# *   왼쪽에서부터 순서대로 연산
# *   0이거나 1이면 더하기 수행
# *   2이상인 경우에는 곱하기

# %% [markdown]
# ![곱하기 더하기 예제.PNG](data:image/png;base64,...)

# %%
data = input()

#첫 번째 문자를 숫자로 변경하여 대입
result = int(data[0])

for i in range(1, len(data)):
    num = int(data[i])
    if num <= 1 or result <= 1:
      result += num
    else:
      result *= num

print(result)
# Out:
# 02984
# 576

# %% [markdown]
# # **모험가 길드**

# %% [markdown]
# *   공포도가 X인 모험가는 반드시 X명 이상으로 구성한 모험가 그룹에 참여
# *   N명의 모험가에 대한 정보가 주어졌을 때 여행을 떠날 수 있는 그룹 수의 최댓값
# *   오름차순 정렬 이후 공포도가 낮은 모험가부터 하나씩 확인

# %% [markdown]
# ![모험가 문제.PNG](data:image/png;base64,...)

# %%
n = int(input())
data = list(map(int, input().split()))
data.sort()

group = 0 #총 그룹의 수
people = 0 #현재 그룹에 포함된 모험가의 수 

for i in data: #공포도가 낮은 것부터 하나씩 확인
    people += 1 #현재 그룹에 해당하는 모험가를 포함시키기
    if people >= i: #현재 그룹에 포함된 모험가의 수가 현재의 공포도 이상, 그룹 결성
        group += 1 #총 그룹의 수 증가시키기
        people = 0 #현재 그룹에 포함된 모험가의 수 초기화

print(group)
# Out:
# 5
# 2 3 1 2 2
# 2

# %% [markdown]
# # **구현**

# %% [markdown]
# 풀이를 떠올리는 것은 쉽지만 소스코드로 옮기기 어려운 문제
#
# *   알고리즘은 간단. 코드가 김
# *   실수 연산. 특정 소수점 자리 출력
# *   문자열을 특정한 기준에 따라 끊어 처리
# *   적절한 라이브러리를 찾아 사용

# %% [markdown]
# 행렬: 2차원 공간

# %%
for i in range(5):
    for j in range(5):
          print('(', i, ',', j, ')', end= ' ')
    print()
# Out:
# ( 0 , 0 ) ( 0 , 1 ) ( 0 , 2 ) ( 0 , 3 ) ( 0 , 4 )
# ( 1 , 0 ) ( 1 , 1 ) ( 1 , 2 ) ( 1 , 3 ) ( 1 , 4 )
# ( 2 , 0 ) ( 2 , 1 ) ( 2 , 2 ) ( 2 , 3 ) ( 2 , 4 )
# ( 3 , 0 ) ( 3 , 1 ) ( 3 , 2 ) ( 3 , 3 ) ( 3 , 4 )
# ( 4 , 0 ) ( 4 , 1 ) ( 4 , 2 ) ( 4 , 3 ) ( 4 , 4 )

# %%
#방향 벡터

#동, 북, 서, 남

dx = [0, -1, 0, 1] #행
dy = [1, 0, -1, 1] #열

#현재 위치
x, y = 2, 2

#다음 위치
for i in range(4):
  nx = x + dx[i]
  ny = y + dy[i]
  print(nx, ny)

# %% [markdown]
# # **상하좌우 문제**
#
# *   시뮬레이션 유형
# *   공간 밖을 벗어나면 무시
# *   문제 요구 사항대로 충실히 구현

# %% [markdown]
# ![상하좌우.PNG](data:image/png;base64,...)

# %% [markdown]
# ![상하좌우 예제.PNG](data:image/png;base64,...)

# %%
n = int(input())
x, y = 1, 1
plans = input().split()

dx = [0, 0, -1, 1]
dy = [-1, 1, 0, 0]
move_types = ['L', 'R', 'U', 'D']

for plan in plans:
      for i in range(len(move_types)):
          if plan == move_types[i]:
                nx = x + dx[i]
                ny = y + dy[i]
      if nx < 1 or ny < 1 or nx > n or ny > n:
          continue
      
      x, y = nx, ny

print(x, y)
# Out:
# 5
# R R R U D D
# 3 4

# %% [markdown]
# # **시각**
# *   완전 탐색 문제
# *   가능한 모든 시각의 경우를 하나씩 모두 세서

# %% [markdown]
# ![시각문제 설명.PNG](data:image/png;base64,...)

# %% [markdown]
# ![시각문제 예제.PNG](data:image/png;base64,...)

# %%
h = int(input())

count = 0

for i in range(h + 1):
    for j in range(60): #분
        for k in range(60):
            if '3' in str(i) + str(j) + str(k):
                count += 1
print(count)
# Out:
# 5
# 11475

# %% [markdown]
# # 왕실의 나이트
# *   요구사항대로 충실히 구현
# *   8가지 경로를 확인하며 각 위치로 이동이 가능한지 확인
# *   리스트를 이용해서 8가지 방향 벡터 정의

# %% [markdown]
# ![왕실의 나이트.PNG](data:image/png;base64,...)

# %% [markdown]
# ![왕실의 나이트 예제.PNG](data:image/png;base64,...)

# %%
#현재 나이트의 위치 입력받기 
input_data = input()
row = int(input_data[1])
column = int(ord(input_data[0])) - int(ord('a')) + 1 #ord 아스키 코드로 바꾸어 줌

steps = [(-2, -1), (-1, -2), (1, -2), (2, -1), (2, 1), (1, 2), (-1, 2), (-2, 1)]

result = 0

for step in steps:

    next_row = row + step[0]
    next_column = column + step[1]

    if next_row >=1 and next_row <=8 and next_column >=1 and next_column <=8:
        result += 1

print(result)
# Out:
# a1
# 2

# %% [markdown]
# # **문자열 재정렬**
#
#
#
# *   알파벳 대문자와 숫자(0~9)로만 구성된 문자열이 입력으로 주어짐
# *   모든 알파벳을 오름차순으로 정렬하고 그 뒤 모든 숫자를 더한 값을 이어서 출력
# * 요구사항대로 충실히 구현
# *   리스트에 저장된 알파벳을 정렬하여 출력하고 합계를 뒤에 붙여 출력

# %% [markdown]
# ![문자열 예제.PNG](data:image/png;base64,...)

# %%
data = input()
result = []
value = 0

for x in data:
    if x.isalpha():
        result.append(x)
    else:
        value += int(x)

result.sort()

if value != 0:
    result.append(str(value))

print(''. join(result))
# Out:
# K1KA5CB7
# ABCKK13
